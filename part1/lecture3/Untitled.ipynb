# %%
1+1
# Out:
# 2

# %%
3+4
# Out:
# 7

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return factorial(n-1) * n

# %%
factorial(10)
# Out:
# 3628800

# %%
factorial(3)
# Out:
# 6

# %%
import tutrle
# Out:
# -------------------------------------------------------------------------
# ImportError                             Traceback (most recent call last)
# <ipython-input-7-f63584d588ce> in <module>()
# ----> 1 import tutrle
#
# ImportError: No module named tutrle

# %%
import Turtle
# Out:
# -------------------------------------------------------------------------
# ImportError                             Traceback (most recent call last)
# <ipython-input-8-6922711c845d> in <module>()
# ----> 1 import Turtle
#
# ImportError: No module named Turtle

# %%
import turtle

# %%
turtle.forward(10)

# %%
turtle.clear()

# %%
turtle.forward(100)

# %%
turtle.left(100)

# %%
turtle.right(10)

# %%
turtle.position
# Out:
# <function turtle.position>

# %%
turtle.position()
# Out:
# (110.00,0.00)

# %%
turtle.forward(100)

# %%
turtle.home()

# %%
turtle.goto(100, 50)

# %%
turtle.forward(10)

# %%
turtle.home()
